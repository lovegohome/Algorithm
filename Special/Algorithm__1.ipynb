# %% [markdown]
# <a href="https://colab.research.google.com/github/lovegohome/Algorithm/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Algorithm 특강
#
# 수업목표
#
#   1. 자료구조 및 알고리즘에 대한 개념 이해
#   2. 파이썬 코딩을 통한 알고리즘 구현

# %% [markdown]
# - 자료구조 : 요리 재료
# - 알고리즘 : 요리 방법

# %% [markdown]
# <자료구조>
#
# 자료(데이터)의 형태 및 구성·관리·저장 *(그릇형태나 서랍형태로 생각하는 것도 좋을 듯)*
#
# - 단순 자료구조(정수, 실수, 문자, 문자열)
# - **선형 자료구조**(선형 & 연결리스트, 스택, 큐)
# - **비선형 자료구조**(트리, 그래프)
# - 파일 자료구조(순차, 색인, 직접 파일)

# %% [markdown]
# <알고리즘>
# - 어떤 문제를 해결해 가는 논리적인 과정, 단계적인 절차
# - 표현법: 일반언어표현 - (순서도) - 의사코드(python, c, java etc 적용가능) - 프로그램 코드
# - 성능 측정: 시간복잡도(Time Complexity)
#
# cf. 컴퓨터 별 속도 달라서 '시간' 자체의 의미가 아니라 '몇 번, 횟수'의 의미로 인식하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <자료구조 & 알고리즘>
#
# 자동차 부품[자료구조] - 조립방법[알고리즘] - 조립[프로그래밍 언어] - 자동차 완성[소프트웨어]
